# %% [markdown]
# ### Q: Why do we remove stop words?
#
# ### Answer:
# ### Stop words are very common words such as is, am, are, the, and. They usually do not contribute much meaning to the text. Removing them reduces noise, decreases dimensionality, and improves NLP model efficiency.

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')                   ## give all stopwords used in english..
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
paragraph = '''All Birds find shelter during a rain.
But Eagle avoids rain by flying above
the Clouds. Problems are common, but attitude
makes the difference!! '''

stop_words=set(stopwords.words('english'))
words=paragraph.split()
filtered_words = []

for word in words:
    if word.lower() not in stop_words:
        filtered_words.append(word)
print(filtered_words)
# Out:
# ['Birds', 'find', 'shelter', 'rain.', 'Eagle', 'avoids', 'rain', 'flying', 'Clouds.', 'Problems', 'common,', 'attitude', 'makes', 'difference!!']

# %% [markdown]
# ### What is the NLP pipeline ?
#
# ### A pipeline is a sequence of processing steps where the output of one step becomes the input of the next step. In NLP, a text preprocessing pipeline may include tokenization, stop word removal, lemmatization, vectorization, and model training.

# %%
import os

# %%
##os.getcwd()

# %%
## A mini preprocessing pipeline

from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize , word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer

# %%
para= '''I have three visions for India.
India can become a developed nation.
We must work hard.'''

# %%
stemmer=PorterStemmer
snowball=SnowballStemmer("english")

# %%
lemma =WordNetLemmatizer()

# %%
## the first step is tokenize whole para.

sentences = sent_tokenize(para)
print(sentences)
# Out:
# ['I have three visions for India.', 'India can become a developed nation.', 'We must work hard.']

# %%
## the second step is tokenize all sentences from the list.

for i in range(len(sentences)):
    words=word_tokenize(sentences[i])
    print(words)
# Out:
# ['I', 'have', 'three', 'visions', 'for', 'India', '.']
# ['India', 'can', 'become', 'a', 'developed', 'nation', '.']
# ['We', 'must', 'work', 'hard', '.']

# %%
## the third step is to stemming all words .
for i in range(len(sentences)):
    
    words=word_tokenize(sentences[i])
    words=[lemma.lemmatize(word) for word in words]
    print(words)
# Out:
# ['I', 'have', 'three', 'vision', 'for', 'India', '.']
# ['India', 'can', 'become', 'a', 'developed', 'nation', '.']
# ['We', 'must', 'work', 'hard', '.']

# %%
## the fourth step is to remove stop words from the above list and then combined and form a sentence without stopwords.
stop_words=set(stopwords.words('english'))
for i in range(len(sentences)):
    
    words=word_tokenize(sentences[i])
    words=[lemma.lemmatize(word) for word in words if word.lower() not in stop_words]
    print(words)
    sentences[i] = ' '. join(words)
# Out:
# ['three', 'vision', 'India', '.']
# ['India', 'become', 'developed', 'nation', '.']
# ['must', 'work', 'hard', '.']

# %%
print(sentences)
# Out:
# ['three vision India .', 'India become developed nation .', 'must work hard .']

# %%
sentences
# Out:
# ['three vision India .', 'India become developed nation .', 'must work hard .']
