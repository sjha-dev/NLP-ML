# %% [markdown]
# # Named Entity Recognition (NER)
#
# ## What is Named Entity Recognition?
#
# Named Entity Recognition (NER) is a Natural Language Processing (NLP) technique used to identify and classify important entities in a text into predefined categories.
#
# Common entity categories include:
#
# - Person Names
# - Organizations
# - Locations
# - Dates
# - Times
# - Money
# - Percentages
#
# NER helps machines understand the real-world meaning of words and phrases in a sentence.
#
# ---
#
# ## Example 1
#
# Sentence:
#
# ```text
# Sudhanshu lives in Delhi and works at Google.
# ```
#
# NER Output:
#
# | Entity | Entity Type |
# |----------|------------|
# | Sudhanshu | PERSON |
# | Delhi | GPE (Location) |
# | Google | ORGANIZATION |
#
# ---
#
# ## Example 2
#
# Sentence:
#
# ```text
# Elon Musk is the CEO of Tesla.
# ```
#
# NER Output:
#
# | Entity | Entity Type |
# |----------|------------|
# | Elon Musk | PERSON |
# | Tesla | ORGANIZATION |
#
# ---
#
# ## Common Entity Types
#
# | Entity Type | Description |
# |------------|-------------|
# | PERSON | Names of people |
# | ORGANIZATION (ORG) | Companies, institutions, organizations |
# | GPE | Countries, cities, states |
# | LOCATION | Physical locations |
# | DATE | Dates |
# | TIME | Time expressions |
# | MONEY | Monetary values |
# | PERCENT | Percentages |
#
# ---
#
# ## POS Tagging vs NER
#
# ### POS Tagging
#
# POS Tagging identifies the grammatical role of a word.
#
# Example:
#
# ```text
# Google → NNP (Proper Noun)
# Delhi → NNP (Proper Noun)
# Sudhanshu → NNP (Proper Noun)
# ```
#
# ### Named Entity Recognition
#
# NER identifies the actual meaning of the entity.
#
# Example:
#
# ```text
# Google → ORGANIZATION
# Delhi → LOCATION
# Sudhanshu → PERSON
# ```
#
# Thus, NER provides more meaningful information than POS Tagging.
#
# ---
#
# ## Why is NER Important?
#
# - Information Extraction
# - Search Engines
# - Chatbots and Virtual Assistants
# - Question Answering Systems
# - News Analysis
# - Recommendation Systems
#
# NER helps computers understand important information from unstructured text.
#
# ---
#
# ## NLTK Implementation
#
# ```python
# import nltk
# from nltk.tokenize import word_tokenize
#
# sentence = "Sudhanshu lives in Delhi and works at Google"
#
# words = word_tokenize(sentence)
#
# pos_tags = nltk.pos_tag(words)
#
# named_entities = nltk.ne_chunk(pos_tags)
#
# print(named_entities)
# ```
#
# ---
#
# ## Expected Output
#
# ```text
# (S
#   (PERSON Sudhanshu)
#   lives
#   in
#   (GPE Delhi)
#   and
#   works
#   at
#   (ORGANIZATION Google))
# ```
#
# ---
#
# ## NLP Pipeline
#
# ```text
# Raw Text
#     ↓
# Sentence Tokenization
#     ↓
# Word Tokenization
#     ↓
# Stopwords Removal
#     ↓
# Stemming / Lemmatization
#     ↓
# POS Tagging
#     ↓
# Named Entity Recognition (NER)
#     ↓
# Feature Extraction
#     ↓
# Machine Learning / Deep Learning
# ```
#
# ---
#
# ## Conclusion
#
# Named Entity Recognition (NER) is an important NLP technique that identifies and classifies real-world entities such as people, organizations, locations, dates, and monetary values. It helps machines understand the context and meaning of text more effectively.

# %%
import nltk
nltk.download('words')
nltk.download('maxent_ne_chunker_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk import word_tokenize

# %%
sentence = "Hello Sir my name is Sudhanshu Shekhar Jha and on 19 January 2003 I was born in Bihar Madhubani and today I am at Google."
words=word_tokenize(sentence)
pos_tag=nltk.pos_tag(words)
print(pos_tag)
named_entities=nltk.ne_chunk(pos_tag)
print(named_entities)
# Out:
# [('Hello', 'NNP'), ('Sir', 'NNP'), ('my', 'PRP$'), ('name', 'NN'), ('is', 'VBZ'), ('Sudhanshu', 'NNP'), ('Shekhar', 'NNP'), ('Jha', 'NNP'), ('and', 'CC'), ('on', 'IN'), ('19', 'CD'), ('January', 'NNP'), ('2003', 'CD'), ('I', 'PRP'), ('was', 'VBD'), ('born', 'VBN'), ('in', 'IN'), ('Bihar', 'NNP'), ('Madhubani', 'NNP'), ('and', 'CC'), ('today', 'NN'), ('I', 'PRP'), ('am', 'VBP'), ('at', 'IN'), ('Google', 'NNP'), ('.', '.')]
# (S
#   (PERSON Hello/NNP)
#   Sir/NNP
#   my/PRP$
#   name/NN
#   is/VBZ
#   (PERSON Sudhanshu/NNP Shekhar/NNP Jha/NNP)
#   and/CC
#   on/IN
#   19/CD
#   January/NNP
#   2003/CD
#   I/PRP
#   was/VBD
#   born/VBN
#   in/IN
#   (GPE Bihar/NNP Madhubani/NNP)
#   and/CC
#   today/NN
#   I/PRP
#   am/VBP
#   at/IN
#   (ORGANIZATION Google/NNP)
#   ./.)

# %%
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk import pos_tag

# %%
line ="Sudhanshu lives in Delhi and works at Google"
words=word_tokenize(line)
print(words)
# Out:
# ['Sudhanshu', 'lives', 'in', 'Delhi', 'and', 'works', 'at', 'Google']

# %%
stop_words = set(stopwords.words("english"))
filtered_words = [
    word for word in words
    if word.lower() not in stop_words
]
print(filtered_words)
# Out:
# ['Sudhanshu', 'lives', 'Delhi', 'works', 'Google']

# %%
pos_result = pos_tag(filtered_words)

# %%
print(pos_result)
# Out:
# [('Sudhanshu', 'NNP'), ('lives', 'VBZ'), ('Delhi', 'NNP'), ('works', 'VBZ'), ('Google', 'NNP')]

# %%
## but if we now want to do NER After stopwords removal then it is completely out of the NLP PIPELINE because NER want to understand context so if you want to do NER then do it , before removal of stopWords .
